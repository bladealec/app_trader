# %% [markdown]
# # App Picture Scraper
# As of now, this script is only focused on scraping application names that are in enlgish and from the google store.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as BS

# %% [markdown]
# #### retrieving .csv as a dataframe

# %%
name_union = pd.read_csv('../app_trader_data/distinct_play_store.csv')
name_union
# Out:
#                      play_store_name
# 0                    BT Communicator
# 1                              E-NUM
# 2                                NaN
# 3                         retteMi.ch
# 4                          Cardboard
# ...                              ...
# 9655  3G to 4G Converter - Simulator
# 9656   Startupticker.ch News, Events
# 9657      Nusenda CU– Mobile Banking
# 9658                   Google Photos
# 9659                    Trivia Crack
#
# [9660 rows x 1 columns]

# %%
name_list = name_union.values.tolist()
name_list
# Out:
# [['BT Communicator'],
#  ['E-NUM'],
#  [nan],
#  ['retteMi.ch'],
#  ['Cardboard'],
#  ['Fashion Girls Dress up Makeup'],
#  ['7 minute abs workout - Daily Ab Workout'],
#  ['Gods by Night'],
#  ['San Andreas Crime Stories'],
#  ['Official QR Code® Reader Q'],
#  ['Beach Head Shooting Assault'],
#  ['Birmingham City FC'],
#  ['Super ABC! Learning games for kids! Preschool apps'],
#  ['Home Scouting® MLS Mobile'],
#  ['Natural recipes for your beauty'],
#  ['Florida Offline Road Map'],
#  ['BEBONCOOL GAMEPAD V1.0'],
#  ['Reading Race 1b: sh, ch words'],
#  ['Plan B'],
#  ['Talking Ginger 2'],
#  ['DZ-JOKER'],
#  ['Bus Rush: Subway Edition'],
#  ['S Photo Editor - Collage Maker , Photo Collage'],
#  ['DreamStream By EL AL'],
#  ['Family GPS Tracker and Chat + Baby Monitor Online'],
#  ['CD Events'],
#  ['WoW AH Tracker'],
#  ['Ag Tools'],
#  ['LC-DB-LITE'],
#  ['Alif Ba Ta Song - Arabic Kids'],
#  ['Formula Cartoon All Stars'],
#  ['JustDating'],
#  ['AJ Rafael Music Lessons'],
# ...

# %% [markdown]
# #### connecting to URL
# - the URL template is https://play.google.com/store/search?q=**app_name**&c=apps
# - spaces in the app name should be replaced with '+'

# %%
URL = 'https://play.google.com/store/search?q=san+andreas+crime+stories+game&c=apps'
response = requests.get(URL)

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# #### reading page elements

# %%
soup = BS(response.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <base href="https://play.google.com/"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="sBw2N8uateIzRr93vmFze5MF_35vMk5F1wG04L5JcJE" name="google-site-verification"/>
#   <meta content="PJKdyVFC5jlu_l8Wo_hirJkhs1cmitmn44fgpOc3zFc" name="google-site-verification"/>
#   <link href="/opensearch.xml" rel="search" title="Google Play" type="application/opensearchdescription+xml"/>
#   <link href="//www.gstatic.com/android/market_images/web/favicon_v3.ico" rel="shortcut icon"/>
#   <script data-id="_gd" nonce="Zq96nt9esG1Eb2KlYKir5Q">
# ...

# %% [markdown]
# #### finding the link to the app's picture

# %%
images = soup.findAll('img')
print(type(images))
images
# Out:
# <class 'bs4.element.ResultSet'>
# [<img aria-hidden="true" class="VfPpkd-kBDsod WrEZCd" src="https://fonts.gstatic.com/s/i/productlogos/avatar_anonymous/v4/web-32dp/logo_avatar_anonymous_color_1x_web_32dp.png" srcset="https://fonts.gstatic.com/s/i/productlogos/avatar_anonymous/v4/web-32dp/logo_avatar_anonymous_color_1x_web_32dp.png 1x, https://fonts.gstatic.com/s/i/productlogos/avatar_anonymous/v4/web-32dp/logo_avatar_anonymous_color_1x_web_32dp.png 2x"/>,
#  <img alt="Screenshot image" aria-hidden="true" class="T75of jpDEN" loading="lazy" src="https://play-lh.googleusercontent.com/C5I2J2zCdFBQgufb9fgH-kfykKv-3-zyAgEm-I6yvuu-rdPJIoo1sO9UAiRTxBGqgA=w416-h235" srcset="https://play-lh.googleusercontent.com/C5I2J2zCdFBQgufb9fgH-kfykKv-3-zyAgEm-I6yvuu-rdPJIoo1sO9UAiRTxBGqgA=w832-h470 2x"/>,
# ...

# %%
picture_link = soup.findAll('div', attrs={'class' : 'Shbxxd'})[0].find('img').get('src')
print(picture_link)
# Out:
# https://play-lh.googleusercontent.com/C5I2J2zCdFBQgufb9fgH-kfykKv-3-zyAgEm-I6yvuu-rdPJIoo1sO9UAiRTxBGqgA=w416-h235

# %% [markdown]
# #### now we need to create a loop to search each app's name and find it's picture link.
